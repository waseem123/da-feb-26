# %% [markdown]
# Assignment : To perform the summation on series data

# %%
import numpy as np
import pandas as pd

# %%
student_marks = {
    'C' : 86,
    'C++' : 78,
    'Java' : 90
}

marks_series = pd.Series(student_marks)
print(marks_series)
# Out:
# C       86
# C++     78
# Java    90
# dtype: int64

# %%
print('Total Marks - ',marks_series.mean())
# Out:
# Total Marks -  84.66666666666667

# %% [markdown]
# Assignment : Display the series with subject having marks greater than 80

# %%
m80 = marks_series[marks_series>80]
print(m80)
# Out:
# C       86
# Java    90
# dtype: int64
