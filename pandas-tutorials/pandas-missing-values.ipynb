# %%
import pandas as pd

# %%
data = {
    'student_name':['Ahmed','Nihal','Onkar','Faiz','Madiha','Tanzila','Gufran'],
    'student_marks':[85,91,None,79,None,81,None]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#   student_name  student_marks
# 0        Ahmed           85.0
# 1        Nihal           91.0
# 2        Onkar            NaN
# 3         Faiz           79.0
# 4       Madiha            NaN
# 5      Tanzila           81.0
# 6       Gufran            NaN

# %%
df_null = df.isnull()
df_null
# Out:
#    student_name  student_marks
# 0         False          False
# 1         False          False
# 2         False           True
# 3         False          False
# 4         False           True
# 5         False          False
# 6         False           True

# %%
df_null.sum()
# Out:
# student_name     0
# student_marks    3
# dtype: int64

# %%
df['student_marks']=df['student_marks'].fillna(0)
df
# Out:
#   student_name  student_marks
# 0        Ahmed           85.0
# 1        Nihal           91.0
# 2        Onkar            0.0
# 3         Faiz           79.0
# 4       Madiha            0.0
# 5      Tanzila           81.0
# 6       Gufran            0.0

# %%
df_updated=df.dropna(axis=0)
df_updated
# Out:
#   student_name  student_marks
# 0        Ahmed           85.0
# 1        Nihal           91.0
# 3         Faiz           79.0
# 5      Tanzila           81.0

# %%
df_updated
# Out:
#   student_name  student_marks
# 0        Ahmed           85.0
# 1        Nihal           91.0
# 3         Faiz           79.0
# 5      Tanzila           81.0
