# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('coursewise_fee.csv')
df
# Out:
#     Unnamed: 0  Sr. No                           Course       Domain  \
# 0            0       1           Full Stack Development         Java
# 1            1       2           Full Stack Development       Python
# 2            2       3                  Ethical Hacking      General
# 3            3       4           Full Stack Development      Dot Net
# 4            4       5           Full Stack Development   MEAN Stack
# 5            5       6           Full Stack Development   MERN Stack
# 6            6       7  Data Science & Machine Learning       Python
# 7            7       8                   Data Analytics       Python
# 8            8       9                  Web Development  HTML/CSS/JS
# 9            9      10          Android App Development       Kotlin
# 10          10      11              iOS App Development        Swift
# 11          11      11              iOS App Development        Swift
# 12          12      12                  Cloud Computing          AWS
# ...

# %%
plt.show()

# %%
df.to_csv('sample.csv')
